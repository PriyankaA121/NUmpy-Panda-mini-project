# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('emp_health.csv')

# %%
data.head()
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.900          0    daily   yes  southwest
# 1  i10013   18    male  33.770          1  weekend    no      south
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
#
#    expenditure
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
data.shape
# Out:
# (1338, 9)

# %%
data.dtypes
# Out:
# id              object
# age              int64
# sex             object
# bmi            float64
# dependent        int64
# alcohol         object
# smoke           object
# zone            object
# expenditure    float64
# dtype: object

# %%
data[(data['age'] > 50) & (data['smoke'] == 'yes')]
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 11    i10023   62  female  26.290          0    daily   yes      south
# 39    i10051   60    male  39.900          0    daily   yes  southwest
# 55    i10067   58    male  36.955          2  weekend   yes  northwest
# 58    i10070   53  female  22.880          1    daily   yes      south
# 86    i10098   57  female  31.160          0       no   yes  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1265  i11277   64    male  23.760          0  weekend   yes  southeast
# 1284  i11296   61    male  36.300          1    daily   yes  southwest
# 1301  i11313   62    male  30.875          3       no   yes       west
# 1321  i11333   62    male  26.695          0    daily   yes       east
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 11    27808.72510
# 39    48173.36100
# 55    47496.49445
# 58    23244.79020
# ...

# %%
# 1. How many employees above 50 age smoke , what is their average expenditure on health management?

# %%
np.mean(data[(data['age'] > 50) & (data['smoke'] == 'yes')]['expenditure'])
# Out:
# 38820.22308234375

# %%
# 2 what is their average expenditure on health management?

# %%
data.head()
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.900          0    daily   yes  southwest
# 1  i10013   18    male  33.770          1  weekend    no      south
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
#
#    expenditure
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
 # 2. How many female employees did not consume alcohol daily.

# %%
data[(data['sex'] == 'female') & (data['alcohol'] !='daily')]['id'].count()
# Out:
# 453

# %%
#there are 453 female employees who did not consume alcohol daily.

# %%
# What is their proportion with respect to total female employees?

# %%
(data['sex'] == 'female').count() /data[(data['sex'] == 'female') & (data['alcohol'] !='daily')]['id'].count()
# Out:
# 2.9536423841059603

# %%
# 2.9536423841059603  is the proportion with respect to total female employees

# %%
data.head()
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.900          0    daily   yes  southwest
# 1  i10013   18    male  33.770          1  weekend    no      south
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
#
#    expenditure
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
#  3. Display zone wise average expenditure of employees on health   >>>>>>>>>>>>> Pending

# %%
data_group_by = data.groupby('zone')
data_group_by.first().mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of                id  age     sex     bmi  dependent  alcohol smoke  expenditure
# zone
# east       i10312   36    male  27.550          3       no    no   6746.74250
# north      i10020   37    male  29.830          2    party    no   6406.41070
# northeast  i10618   27  female  25.175          0       no    no   3558.62025
# northwest  i10015   33    male  22.705          0    daily    no  21984.47061
# south      i10013   18    male  33.770          1  weekend    no   1725.55230
# southeast  i10314   56  female  37.510          2  weekend    no  12265.50690
# southwest  i10012   19  female  27.900          0    daily   yes  16884.92400
# west       i10311   48  female  28.880          1    party    no   9249.49520>

# %%
# 4. Employees of which zone did maximum expenditure on health

# %%
data.head()
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.900          0    daily   yes  southwest
# 1  i10013   18    male  33.770          1  weekend    no      south
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
#
#    expenditure
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
data_group_by.expenditure.first().max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of zone
# east          6746.74250
# north         6406.41070
# northeast     3558.62025
# northwest    21984.47061
# south         1725.55230
# southeast    12265.50690
# southwest    16884.92400
# west          9249.49520
# Name: expenditure, dtype: float64>

# %%
data.head()
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.900          0    daily   yes  southwest
# 1  i10013   18    male  33.770          1  weekend    no      south
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
#
#    expenditure
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
# 5 What is the minimum expenditure done by any employee in organization

data["expenditure"].min()
# Out:
# 1121.8739

# %%
# 6 What is average expenditure of employees who have 2 or lesser dependents
data[(data['dependent'] <=2)]['expenditure'].mean()
# Out:
# 13040.970970948145

# %%
# 7 How many employees are below age of 20 years. What is their average BMI
a=data[(data['age']<20)]
print(a['age'].count())
a['bmi'].mean()

#answere there are 137 people below age 20and their mean is 29.971496350364966.
# Out:
# 137
# 29.971496350364966

# %%
data.head()
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.900          0    daily   yes  southwest
# 1  i10013   18    male  33.770          1  weekend    no      south
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
#
#    expenditure
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
# 8 Create a dataframe "non_smoker" for all non-smoker male employees
                    
non_smoker = data.loc[(data['sex']== 'male') & (data['smoke'] == "no"), ['sex','smoke']]
non_smoker
#rename columns
non_smoker = non_smoker.rename(columns={'sex':'Sex','smoke':'non_smoker'})
non_smoker
# Out:
#        Sex non_smoker
# 1     male         no
# 2     male         no
# 3     male         no
# 4     male         no
# 8     male         no
# ...    ...        ...
# 1324  male         no
# 1325  male         no
# 1327  male         no
# 1329  male         no
# 1333  male         no
#
# [517 rows x 2 columns]

# %%
# 9 Create a dataframe "non_alcoholic" for all male employees who do not consume alcohol
non_alcoholic= data.loc[(data['sex']== 'male') & 
               (data['alcohol']== "no" )  , ['sex','alcohol']]
non_alcoholic
non_alcoholic = non_alcoholic.rename(columns={'sex':'Sex','alcohol':'non_alcoholic'})
non_alcoholic
# Out:
#        Sex non_alcoholic
# 18    male            no
# 24    male            no
# 28    male            no
# 37    male            no
# 38    male            no
# ...    ...           ...
# 1291  male            no
# 1301  male            no
# 1310  male            no
# 1320  male            no
# 1333  male            no
#
# [147 rows x 2 columns]

# %%
data.head()
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.900          0    daily   yes  southwest
# 1  i10013   18    male  33.770          1  weekend    no      south
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
#
#    expenditure
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
# 10 Create a dataframe called "non_smoking_alcoholic" with the men employees 
#who do not smoke and consume alcohol. The dataframe should contain columns id, smoke, alcohol
 #(Hint:Use join and dataframes created in Q8 and Q9)
non_smoking_alcoholic=data.loc[(data['smoke'] == "no")& 
                              (data['alcohol']== "no" )  , ['id','smoke','alcohol']]

non_smoking_alcoholic
# Out:
#           id smoke alcohol
# 5     i10017    no      no
# 9     i10021    no      no
# 18    i10030    no      no
# 24    i10036    no      no
# 28    i10040    no      no
# ...      ...   ...     ...
# 1311  i11323    no      no
# 1320  i11332    no      no
# 1326  i11338    no      no
# 1330  i11342    no      no
# 1333  i11345    no      no
#
# [197 rows x 3 columns]

# %%
# 11 What is the count for each zone with respect to number of dependent
data_group_by=data.groupby(['dependent','zone'])['dependent'].count()
data_group_by
# Out:
# dependent  zone
# 0          east         124
#            north         26
#            northeast     35
#            northwest     70
#            south         38
#            southeast     81
#            southwest    116
#            west          84
# 1          east          65
#            north         20
#            northeast      9
#            northwest     28
#            south         21
#            southeast     57
#            southwest     53
#            west          71
# 2          east          42
#            north         10
#            northeast     15
#            northwest     30
#            south         12
#            southeast     38
#            southwest     44
#            west          49
# 3          east          22
#            north         12
#            northeast     13
#            northwest     13
#            south         12
#            southeast     15
#            southwest     25
#            west          45
# ...

# %%
# 12 Classify the employees into 3 categories.
#  Category 1 : employees below 18.5 bmi - underweight
#  Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit
#  Category 3 : employee with bmi over 24.9 - overweight
#  What is the average expenditure of employees in each category.

under_weight = data[data['bmi'] < 18.5]
print(under_weight['expenditure'].mean())

fit = data[(data['bmi'] >= 18.5) & (data['bmi'] >= 24.9)]
print(fit['expenditure'].mean())

over_weight = data[data['bmi'] > 24.9]
print(over_weight['expenditure'].mean())
# Out:
# 8852.200585000002
# 13936.616823466235
# 13936.616823466235

# %%
 #13. Draw line plot of expenditure against age and BMI
import matplotlib.pyplot as plt
data.plot.line(x='expenditure',y=['age','bmi'])
plt.xlabel("expenditure")
plt.ylabel("'age','bmi'")
# Out:
# Text(0, 0.5, "'age','bmi'")

# %%
import seaborn as sns
sns.barplot(x="zone", y="expenditure", data=data)
# Out:
# <AxesSubplot:xlabel='zone', ylabel='expenditure'>

# %%
# 14. Draw a bar chart to show zone wise average expenditure
x = data.groupby('zone')['expenditure'].mean()
x.plot(kind='bar')
plt.xlabel("Zone")
plt.ylabel("Expenditure")
# Out:
# Text(0, 0.5, 'Expenditure')

# %%
# 15 Draw a bar chart to show smoking and alcoholic habits against average expenditure
import seaborn as sns
x = data.groupby(['smoke','alcohol'])['expenditure'].mean()
x.plot(kind='bar')

plt.ylabel("Expenditure")
# Out:
# Text(0, 0.5, 'Expenditure')

# %%
ax = sns.barplot(x="smoke", y='expenditure', hue="smoke", data=data)

# %%
ax = sns.barplot(x="alcohol", y='expenditure', hue="alcohol", data=data)

# %%
 #16. Draw pie chart for alcohol consumption habits

d=data.groupby('alcohol').size()
plt.pie(d,autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2470c29cca0>,
# ...
#  [Text(0.6598631335250115, 0.8801026332278259, ''),
#   Text(-0.8563214808580007, 0.6904444376060689, ''),
#   Text(-0.9187211110856004, -0.6049392697169197, ''),
#   Text(-0.21554927483423952, -1.0786744226681346, ''),
#   Text(0.7546570106519398, -0.8003079384048856, '')],
#  [Text(0.35992534555909717, 0.48005598176063224, '29.5%'),
#   Text(-0.467084444104364, 0.37660605687603754, '19.4%'),
#   Text(-0.5011206060466911, -0.3299668743910471, '20.8%'),
#   Text(-0.117572331727767, -0.5883678669098916, '4.4%'),
#   Text(0.41163109671923986, -0.43653160276630115, '25.9%')])

# %%
#17. Draw scatterplot to see the relation between age and expenditure, keep smoking habit as hue
age = data.groupby(['age','expenditure'])

sns.scatterplot(x='age',y='expenditure',data=data,hue='smoke')
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenditure'>

# %%
# 18. Draw distribution plot of expenditure
sns.displot(data, x="expenditure")

# %%
#19 Display the pairplot
sns.pairplot(data,hue='sex')
plt.show()

# %%
#20 Display heatmap for the data


sns.heatmap(data.corr(),annot=True,cmap='summer')
# Out:
# <AxesSubplot:>
